# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
diabetes_X,diabetes_y = load_diabetes(return_X_y = True)

# %%
pd.DataFrame(diabetes_X)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
pd.Series(diabetes_y)
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Length: 442, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(pd.DataFrame(diabetes_X),pd.Series(diabetes_y),test_size = 0.25,random_state = 100)

X_train = X_train.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

print("Size of X_train: ",X_train.shape)
print("Size of X_test: ",X_test.shape)
print("Size of y_train: ",y_train.shape)
print("Size of y_test: ",X_test.shape)
# Out:
# Size of X_train:  (331, 10)
# Size of X_test:  (111, 10)
# Size of y_train:  (331,)
# Size of y_test:  (111, 10)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)

# %%
# Mean squared error: (sum(y_actual-y_predicted)^2)/2
# R squared: (sum(y_actual-y_predicted)^2)/sum(y_actual-y_mean)^2)
print('Mean squared error for training set:%.2f'%mean_squared_error(y_train,y_train_pred))
print('Coefficient of determination set:%.2f'%r2_score(y_train,y_train_pred))
# Out:
# Mean squared error for training set:2947.93
# Coefficient of determination set:0.51

# %%
y_test_pred = model.predict(X_test)

# %%
print('Mean squared error for training set:%.2f'%mean_squared_error(y_test,y_test_pred))
print('Coefficient of determination set:%.2f'%r2_score(y_test,y_test_pred))
# Out:
# Mean squared error for training set:2665.23
# Coefficient of determination set:0.53

# %%
print('Coefficients:',model.coef_)
# Out:
# Coefficients: [ -35.95661515 -204.78535938  567.84433795  288.69956947 -811.64094338
#   496.1636676   118.10092081   84.08425404  817.01449756   60.90313155]

# %%
data = pd.read_csv('demo2_data.csv')
data
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
data.waterfront = data.waterfront.map({'Yes' : 1,'No' : 0})
data
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
# pearson correlation 
# sum((x-x_mean)*(y-y_mean))/square_root(sum(x-x_mean)^2)* sum((y-y_mean)^2)
corrs = data.corr()
plt.figure(figsize = (16,12))
sns.heatmap(corrs,annot = True,fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
X = data.iloc[:,2:] 
y = data.iloc[:,1:2]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 100)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

print("Size of X_train:",X_train.shape)
print("Size of X_test:",X_test.shape)
print("Size of y_train:",y_train.shape)
print("Size of y_test:",y_test.shape)
# Out:
# Size of X_train: (17290, 18)
# Size of X_test: (4323, 18)
# Size of y_train: (17290, 1)
# Size of y_test: (4323, 1)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
regressor = LinearRegression()
regressor.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = regressor.predict(X_train_scaled)

# %%
print('Mean squared error for training set:%.2f'%mean_squared_error(y_train,y_train_pred))
print('Coefficient of determination set:%.2f'%r2_score(y_train,y_train_pred))
# Out:
# Mean squared error for training set:40657974067.87
# Coefficient of determination set:0.70

# %%
y_test_pred = regressor.predict(X_test_scaled)

# %%
print('Mean squared error for training set:%.2f'%mean_squared_error(y_test,y_test_pred))
print('Coefficient of determination set:%.2f'%r2_score(y_test,y_test_pred))
# Out:
# Mean squared error for training set:40094666281.55
# Coefficient of determination set:0.70
